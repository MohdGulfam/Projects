# %%
import pandas as pd
import numpy as np 
import sklearn 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Bk=pd.read_csv("hour.csv")
Bk
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 0            1  2011-01-01       1   0     1   0        0        6
# 1            2  2011-01-01       1   0     1   1        0        6
# 2            3  2011-01-01       1   0     1   2        0        6
# 3            4  2011-01-01       1   0     1   3        0        6
# 4            5  2011-01-01       1   0     1   4        0        6
# 5            6  2011-01-01       1   0     1   5        0        6
# 6            7  2011-01-01       1   0     1   6        0        6
# 7            8  2011-01-01       1   0     1   7        0        6
# 8            9  2011-01-01       1   0     1   8        0        6
# 9           10  2011-01-01       1   0     1   9        0        6
# 10          11  2011-01-01       1   0     1  10        0        6
# 11          12  2011-01-01       1   0     1  11        0        6
# 12          13  2011-01-01       1   0     1  12        0        6
# ...

# %%
Bk.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
Bk.dtypes
# Out:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# hr              int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %%
Bk.shape
# Out:
# (17379, 17)

# %%
Bk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
# instant       17379 non-null int64
# dteday        17379 non-null object
# season        17379 non-null int64
# yr            17379 non-null int64
# mnth          17379 non-null int64
# hr            17379 non-null int64
# holiday       17379 non-null int64
# weekday       17379 non-null int64
# workingday    17379 non-null int64
# weathersit    17379 non-null int64
# temp          17379 non-null float64
# atemp         17379 non-null float64
# hum           17379 non-null float64
# windspeed     17379 non-null float64
# casual        17379 non-null int64
# registered    17379 non-null int64
# cnt           17379 non-null int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
Bk.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %%
Bk.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
sns.heatmap(Bk.isnull())

# %%
sns.distplot(Bk['instant'])

# %%
sns.distplot(Bk['temp'])

# %%
Bk.skew()
# Out:
# instant       0.000000
# season       -0.005416
# yr           -0.010243
# mnth         -0.009253
# hr           -0.010680
# holiday       5.638538
# weekday      -0.002998
# workingday   -0.785258
# weathersit    1.228047
# temp         -0.006021
# atemp        -0.090429
# hum          -0.111287
# windspeed     0.574905
# casual        2.499237
# registered    1.557904
# cnt           1.277412
# dtype: float64

# %%
sns.distplot(Bk['holiday'])

# %%
sns.distplot(Bk['casual'])

# %%
from scipy.stats import boxcox

# %%
Bk['holiday']=boxcox(Bk['holiday'],0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-91a477caf54f> in <module>
# ----> 1 Bk['holiday']=boxcox(Bk['holiday'],0)
#
# ~\Anaconda3\lib\site-packages\scipy\stats\morestats.py in boxcox(x, lmbda, alpha)
#    1030
#    1031     if any(x <= 0):
# -> 1032         raise ValueError("Data must be positive.")
#    1033
#    1034     if lmbda is not None:  # single transformation
#
# ValueError: Data must be positive.

# %%
helpful_log = np.log(Bk['holiday'])
helpful_log.describe()
# Out:
# C:\Users\Welcome\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.
# C:\Users\Welcome\Anaconda3\lib\site-packages\numpy\lib\function_base.py:3942: RuntimeWarning: invalid value encountered in multiply
#   x2 = take(ap, indices_above, axis=axis) * weights_above
# count    17379.0
# mean        -inf
# std          NaN
# min         -inf
# 25%         -inf
# 50%          NaN
# 75%         -inf
# max          0.0
# Name: holiday, dtype: float64

# %%
Bk.skew()
# Out:
# instant       0.000000
# season       -0.005416
# yr           -0.010243
# mnth         -0.009253
# hr           -0.010680
# holiday       5.638538
# weekday      -0.002998
# workingday   -0.785258
# weathersit    1.228047
# temp         -0.006021
# atemp        -0.090429
# hum          -0.111287
# windspeed     0.574905
# casual        2.499237
# registered    1.557904
# cnt           1.277412
# dtype: float64

# %%
Bk['casual']=boxcox(Bk['casual'],0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-3cfebe7c6d65> in <module>
# ----> 1 Bk['casual']=boxcox(Bk['casual'],0)
#
# ~\Anaconda3\lib\site-packages\scipy\stats\morestats.py in boxcox(x, lmbda, alpha)
#    1030
#    1031     if any(x <= 0):
# -> 1032         raise ValueError("Data must be positive.")
#    1033
#    1034     if lmbda is not None:  # single transformation
#
# ValueError: Data must be positive.

# %%
x=Bk.loc[:,('instant','season','holiday','weekdays','workingdays','temp','atemp','hum')]
x.head()
# Out:
# C:\Users\Welcome\Anaconda3\lib\site-packages\pandas\core\indexing.py:868: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_lowerdim(tup)
#    instant  season  holiday  weekdays  workingdays  temp   atemp   hum
# 0        1       1        0       NaN          NaN  0.24  0.2879  0.81
# 1        2       1        0       NaN          NaN  0.22  0.2727  0.80
# 2        3       1        0       NaN          NaN  0.22  0.2727  0.80
# 3        4       1        0       NaN          NaN  0.24  0.2879  0.75
# 4        5       1        0       NaN          NaN  0.24  0.2879  0.75

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()
