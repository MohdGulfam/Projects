# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
Sc=pd.read_csv('Advertising.csv')
Sc.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
Sc.tail()
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %%
Sc_new=Sc.drop(['Unnamed: 0'],axis=1)

# %%
Sc_new.tail()
# Out:
#         TV  radio  newspaper  sales
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4

# %%
Sc=Sc_new

# %%
Sc.shape
# Out:
# (200, 4)

# %%
Sc.dtypes
# Out:
# TV           float64
# radio        float64
# newspaper    float64
# sales        float64
# dtype: object

# %%
Sc.keys()
# Out:
# Index(['TV', 'radio', 'newspaper', 'sales'], dtype='object')

# %%
Sc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
# TV           200 non-null float64
# radio        200 non-null float64
# newspaper    200 non-null float64
# sales        200 non-null float64
# dtypes: float64(4)
# memory usage: 6.3 KB

# %%
Sc.isnull().sum()
# Out:
# TV           0
# radio        0
# newspaper    0
# sales        0
# dtype: int64

# %%
sns.heatmap(Sc.isnull())

# %%
Sc.describe()
# Out:
#                TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
 Sc.hist(figsize=(10,10), grid=False, layout=(3, 4), bins = 30)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000262AA486198>,
# ...
#       dtype=object)

# %%
Sc.skew()
# Out:
# TV          -0.069853
# radio        0.094175
# newspaper    0.894720
# sales        0.407571
# dtype: float64

# %%
Sc['TV'].plot.box()

# %%
Sc['radio'].plot.box()

# %%
Sc['newspaper'].plot.box()

# %%
Sc['sales'].plot.box()

# %%
sns.distplot(Sc['TV'],kde=False)

# %%
sns.pairplot(Sc, hue="sales")
# Out:
# C:\Users\Welcome\Anaconda3\lib\site-packages\numpy\core\_methods.py:140: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# C:\Users\Welcome\Anaconda3\lib\site-packages\numpy\core\_methods.py:132: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\Welcome\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\Welcome\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
sns.jointplot(x='sales',y="TV",data=Sc,color='red')

# %%
sns.jointplot(x='sales',y="radio",data=Sc,color='red')

# %%
sns.jointplot(x='sales',y="newspaper",data=Sc,color='red')

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(Sc))
z
# Out:
# array([[9.69852266e-01, 9.81522472e-01, 1.77894547e+00, 1.55205313e+00],
#        [1.19737623e+00, 1.08280781e+00, 6.69578760e-01, 6.96046111e-01],
#        [1.51615499e+00, 1.52846331e+00, 1.78354865e+00, 9.07405869e-01],
#        [5.20496822e-02, 1.21785493e+00, 1.28640506e+00, 8.60330287e-01],
#        [3.94182198e-01, 8.41613655e-01, 1.28180188e+00, 2.15683025e-01],
#        [1.61540845e+00, 1.73103399e+00, 2.04592999e+00, 1.31091086e+00],
#        [1.04557682e+00, 6.43904671e-01, 3.24708413e-01, 4.27042783e-01],
#        [3.13436589e-01, 2.47406325e-01, 8.72486994e-01, 1.58039455e-01],
#        [1.61657614e+00, 1.42906863e+00, 1.36042422e+00, 1.77205942e+00],
#        [6.16042873e-01, 1.39530685e+00, 4.30581584e-01, 6.57617064e-01],
#        [9.45155670e-01, 1.17923146e+00, 2.92486143e-01, 1.04190753e+00],
#        [7.90028350e-01, 4.96973404e-02, 1.22232878e+00, 6.48970529e-01],
#        [1.43908760e+00, 7.99208859e-01, 1.62704048e+00, 9.26620392e-01],
# ...

# %%
thershold=3
print(np.where(z>3))
# Out:
# (array([ 16, 101], dtype=int64), array([2, 2], dtype=int64))

# %%
Sc=Sc[(z<3).all(axis=1)]

# %%
Sc.shape
# Out:
# (198, 4)

# %%
x=Sc.drop('sales',axis=1)
x.head()
# Out:
#       TV  radio  newspaper
# 0  230.1   37.8       69.2
# 1   44.5   39.3       45.1
# 2   17.2   45.9       69.3
# 3  151.5   41.3       58.5
# 4  180.8   10.8       58.4

# %%
y=Sc['sales']
y.head()
# Out:
# 0    22.1
# 1    10.4
# 2     9.3
# 3    18.5
# 4    12.9
# Name: sales, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=33,random_state=42)

# %%
x_train.shape
# Out:
# (33, 3)

# %%
x_test.shape
# Out:
# (165, 3)

# %%
y_train.shape
# Out:
# (33,)

# %%
y_test.shape
# Out:
# (165,)

# %%
y=y.values.reshape(-1,1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-252-ea92f94b1431> in <module>
# ----> 1 y=y.values.reshape(-1,1)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'values'

# %%
y_train.shape
# Out:
# (33,)

# %%
y_test.shape
# Out:
# (165,)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn import preprocessing
from sklearn import utils

# %%
lab_enc = preprocessing.LabelEncoder()
training_scores_encoded = lab_enc.fit_transform(y_train)
print(training_scores_encoded)
print(utils.multiclass.type_of_target(y_train))
print(utils.multiclass.type_of_target(y_train.astype('int')))
print(utils.multiclass.type_of_target(training_scores_encoded))
# Out:
# [ 9  6 22  6 21  1 28 18  3 15  7 16 20  8 26 11  2 23 24 12 20 16  4 19
#  17 14 10  5  0 23 27 13 25]
# continuous
# multiclass
# multiclass

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-271-166d6099ca59> in <module>
#       1 knn = KNeighborsClassifier(n_neighbors=5)
# ----> 2 knn.fit(x_train, y_train)
#
# ~\Anaconda3\lib\site-packages\sklearn\neighbors\base.py in fit(self, X, y)
#     904             self.outputs_2d_ = True
#     905
# --> 906         check_classification_targets(y)
#     907         self.classes_ = []
#     908         self._y = np.empty(y.shape, dtype=np.int)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\multiclass.py in check_classification_targets(y)
#     167     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     168                       'multilabel-indicator', 'multilabel-sequences']:
# --> 169         raise ValueError("Unknown label type: %r" % y_type)
#     170
#     171
#
# ValueError: Unknown label type: 'continuous'

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
decision_tree = DecisionTreeClassifier(random_state=0, max_depth=2)
decision_tree = decision_tree.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-277-6b2dd7ec918c> in <module>
#       1 decision_tree = DecisionTreeClassifier(random_state=0, max_depth=2)
# ----> 2 decision_tree = decision_tree.fit(x_train,y_train)
#
# ~\Anaconda3\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     814             sample_weight=sample_weight,
#     815             check_input=check_input,
# --> 816             X_idx_sorted=X_idx_sorted)
#     817         return self
#     818
#
# ~\Anaconda3\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     152
#     153         if is_classification:
# --> 154             check_classification_targets(y)
#     155             y = np.copy(y)
#     156
#
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
pred=lm.predict(x_test)

# %%
print(pred)
# Out:
# [ 8.77037792 11.64610945 22.99850554  8.49053133 10.50291395 21.85946061
#  18.97337736 11.15206941 13.83666391 17.24169586 13.88174482 20.75773054
#   8.57925975 12.42024001  6.19322405  8.65485656 10.7465137  12.02807672
#   9.67982083 11.38324483 12.9730894  17.00011888 22.70717447  5.88289632
#  16.86315933 20.8350487   7.88924084 14.03823636  6.66612137 11.80134595
#  17.52657338 13.5215556   6.17738027 14.43667103 14.98260371 18.13720461
#  14.94923595 11.47258698 17.8901453  15.91793869 19.29660637 12.85279775
#  11.61156968  9.19906322  5.97936061  7.44489253 16.89634438 15.90583405
#  10.79241    22.91722232 16.70026825 13.49514832 18.4765776   5.06374104
#   4.21772937 12.02843596  9.32580703 21.24715889 13.57975178 10.6496346
#  20.45252959  7.14353613 20.1494134   7.32516011 23.86668289 13.14123752
#  20.95228561 10.7936402   8.05219696 16.55735079 18.40717412  4.30906059
#  17.03916805 12.61662312 21.34544342 20.59873386 12.24776381 12.04987383
# ...

# %%
lm.coef_
# Out:
# array([0.04418746, 0.19432118, 0.00505342])

# %%
lm.intercept_
# Out:
# 2.587054428892845

# %%
lm.score(x_train,y_train)
# Out:
# 0.9001317972577636

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
print('error')
print("mean absolute error:",mean_absolute_error(y_test,pred))
print("mean square error",mean_squared_error(y_test,pred))
print('rooot mean square error',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# error
# mean absolute error: 1.333732591270533
# mean square error 3.023283756138262
# rooot mean square error 1.7387592576714759

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,pred))
# Out:
# 0.8891780924163597

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,pred))
# Out:
# 0.8891780924163597

# %%
from sklearn.externals import joblib
joblib.dump(lm,'saleschannal.pkl')
# Out:
# ['saleschannal.pkl']
