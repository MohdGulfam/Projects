# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
from sklearn.model_selection import train_test_split

# %%
Hd=pd.read_csv('heart.csv')

# %%
Hd.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
Hd.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %%
Hd.keys()
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
Hd.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
Hd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
# age         303 non-null int64
# sex         303 non-null int64
# cp          303 non-null int64
# trestbps    303 non-null int64
# chol        303 non-null int64
# fbs         303 non-null int64
# restecg     303 non-null int64
# thalach     303 non-null int64
# exang       303 non-null int64
# oldpeak     303 non-null float64
# slope       303 non-null int64
# ca          303 non-null int64
# thal        303 non-null int64
# target      303 non-null int64
# dtypes: float64(1), int64(13)
# memory usage: 33.2 KB

# %%
Hd.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
sns.heatmap(Hd.isnull())

# %%
Hd.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
Hd.skew()
# Out:
# age        -0.202463
# sex        -0.791335
# cp          0.484732
# trestbps    0.713768
# chol        1.143401
# fbs         1.986652
# restecg     0.162522
# thalach    -0.537410
# exang       0.742532
# oldpeak     1.269720
# slope      -0.508316
# ca          1.310422
# thal       -0.476722
# target     -0.179821
# dtype: float64

# %%
Hd['chol'] = np.log(Hd['chol'])
Hd['chol'].describe()
# Out:
# count    303.000000
# mean       5.485514
# std        0.203808
# min        4.836282
# 25%        5.351858
# 50%        5.480639
# 75%        5.614950
# max        6.335054
# Name: chol, dtype: float64

# %%
Hd.skew()
# Out:
# age        -0.202463
# sex        -0.791335
# cp          0.484732
# trestbps    0.713768
# chol        0.086667
# fbs         1.986652
# restecg     0.162522
# thalach    -0.537410
# exang       0.742532
# oldpeak     1.269720
# slope      -0.508316
# ca          1.310422
# thal       -0.476722
# target     -0.179821
# dtype: float64

# %%
sns.distplot(Hd['chol'])

# %%
Hd['age'].plot.box()

# %%
Hd['cp'].plot.box()

# %%
Hd['trestbps'].plot.box()

# %%
Hd['chol'].plot.box()

# %%
Hd['fbs'].plot.box()

# %%
Hd['oldpeak'].plot.box()

# %%
Hd['ca'].plot.box()

# %%
Hd['slope'].plot.box()

# %%
Hd['thal'].plot.box()

# %%
Hd['target'].plot.box()

# %%
sns.scatterplot(x='age',y='cp',hue='sex',data=Hd)

# %%
sns.heatmap(Hd.corr(),vmax = 1, vmin = 0,annot = True)
plt.show()

# %%
sns.catplot(x="age", y="thal", hue="sex",col="exang", kind = 'bar',data=Hd, palette = "rainbow")

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(Hd))
z
# Out:
# array([[0.9521966 , 0.68100522, 1.97312292, ..., 0.71442887, 2.14887271,
#         0.91452919],
#        [1.91531289, 0.68100522, 1.00257707, ..., 0.71442887, 0.51292188,
#         0.91452919],
#        [1.47415758, 1.46841752, 0.03203122, ..., 0.71442887, 0.51292188,
#         0.91452919],
#        ...,
#        [1.50364073, 0.68100522, 0.93851463, ..., 1.24459328, 1.12302895,
#         1.09345881],
#        [0.29046364, 0.68100522, 0.93851463, ..., 0.26508221, 1.12302895,
#         1.09345881],
#        [0.29046364, 1.46841752, 0.03203122, ..., 0.26508221, 0.51292188,
#         1.09345881]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 48,  85,  92, 111, 158, 163, 164, 204, 221, 223, 251, 272, 281],
#       dtype=int64), array([12,  4, 11,  4, 11, 11, 11,  9,  9,  3, 11,  7, 12], dtype=int64))

# %%
Hd=Hd[(z<3).all(axis=1)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-106-bb2dd6cb87a5> in <module>
# ----> 1 Hd=Hd[(z<3).all(axis=1)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2916         # Do we have a (boolean) 1d indexer?
#    2917         if com.is_bool_indexer(key):
# -> 2918             return self._getitem_bool_array(key)
#    2919
#    2920         # We are left with two options: a single key, and a collection of keys,
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_bool_array(self, key)
#    2961         elif len(key) != len(self.index):
#    2962             raise ValueError('Item wrong length %d instead of %d.' %
# -> 2963                              (len(key), len(self.index)))
#    2964
#    2965         # check_bool_indexer will throw exception if Series key cannot
#
# ...

# %%
sns.pairplot(Hd)

# %%
x=Hd.drop('target',axis=1)

# %%
x.shape
# Out:
# (290, 13)

# %%
y.shape
# Out:
# (290,)

# %%
y=y.values.reshape(-1,1)

# %%
y.shape
# Out:
# (290, 1)

# %%
y=Hd['target']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=33,random_state=42)

# %%
x_train.shape
# Out:
# (33, 13)

# %%
x_test.shape
# Out:
# (257, 13)

# %%
y_train.shape
# Out:
# (33,)

# %%
y_test.shape
# Out:
# (257,)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DT=DecisionTreeClassifier()

# %%
DT=DT.fit(x_train,y_train)

# %%
pred=DT.predict(x_test)

# %%
print(x_test)
# Out:
#      age  sex  cp  trestbps      chol  fbs  restecg  thalach  exang  oldpeak  \
# 86    68    1   2  4.770685  5.624018    0        1      151      0      1.0
# 269   56    1   0  4.867534  5.645447    1        0      103      1      1.6
# 45    52    1   1  4.787492  5.783825    0        1      172      0      0.2
# 182   61    0   0  4.867534  5.799093    0        0      169      0      0.0
# 147   60    0   3  5.010635  5.480639    0        1      171      0      0.9
# 129   74    0   1  4.787492  5.594711    0        0      121      1      0.2
# 234   70    1   0  4.867534  5.774552    0        0      109      0      2.4
# 122   41    0   2  4.718499  5.590987    0        0      172      1      0.0
# 9     57    1   2  5.010635  5.123964    0        1      174      0      1.6
# 93    54    0   1  4.882802  5.662960    1        0      159      1      0.0
# 151   71    0   0  4.718499  5.003946    0        1      125      0      1.6
# ...

# %%
from sklearn.metrics import accuracy_score

# %%
print('accuracy '),accuracy_score(pred,y_test)
# Out:
# accuracy
# (None, 0.6809338521400778)

# %%
from sklearn.model_selection import cross_val_score

# %%
dtc=DecisionTreeClassifier(criterion='gini')
score=cross_val_score(dtc,x,y,cv=5,scoring='f1_macro')
print('mean score',score.mean())
print('standard deviation ',score.std() )
# Out:
# mean score 0.7475968938013627
# standard deviation  0.02427253694056033

# %%
from sklearn.metrics import confusion_matrix

# %%
print('confusion matrix ',confusion_matrix(pred,y_test))
# Out:
# confusion matrix  [[81 48]
#  [34 94]]

# %%
from sklearn.externals import joblib
joblib.dump(Hd,'heartdisease.pkl')
# Out:
# C:\Users\Welcome\Anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
# ['heartdisease.pkl']
