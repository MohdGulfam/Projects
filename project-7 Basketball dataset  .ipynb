# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,mean_absolute_error
import warnings
warnings.filterwarnings('ignore')

# %%
Bl=pd.read_csv('baseball.csv')
Bl.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
Bl.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
Bl.shape
# Out:
# (30, 17)

# %%
Bl.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
Bl.keys()
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
Bl.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
sns.heatmap(Bl.isnull())

# %%
Bl.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
 Bl.hist(figsize=(15,15), grid=False, layout=(4, 5), bins = 30)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000021B03B4EA20>,
# ...
#       dtype=object)

# %%
Bl.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
from scipy.stats import boxcox

# %%
Bl['R']=boxcox(Bl['R'],0)

# %%
Bl.skew()
# Out:
# W      0.047089
# R      0.744196
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
sns.distplot(Bl['W'])

# %%
sns.distplot(Bl['R'])

# %%
sns.distplot(Bl['AB'])

# %%
sns.distplot(Bl['H'])

# %%
sns.distplot(Bl['2B'])

# %%
sns.distplot(Bl['3B'])

# %%
sns.distplot(Bl['HR'])

# %%
sns.distplot(Bl['BB'])

# %%
sns.distplot(Bl['SO'])

# %%
sns.distplot(Bl['SB'])

# %%
sns.distplot(Bl['RA'])

# %%
sns.distplot(Bl['ER'])

# %%
sns.distplot(Bl['ERA'])

# %%
sns.distplot(Bl['CG'])

# %%
sns.distplot(Bl['SHO'])

# %%
sns.distplot(Bl['SV'])

# %%
sns.distplot(Bl['E'])

# %%
sns.jointplot(x='W',y='R',data=Bl,color='green')

# %%
sns.jointplot(x='W',y='AB',data=Bl,color='green')

# %%
sns.jointplot(x='W',y='H',data=Bl,color='green')

# %%
sns.jointplot(x='W',y='2B',data=Bl,color='green')

# %%
sns.jointplot(x='W',y='3B',data=Bl,color='green')

# %%
sns.jointplot(x='W',y='HR',data=Bl,color='green')

# %%
sns.jointplot(x='W',y='BB',data=Bl,color='green')

# %%
sns.jointplot(x='W',y='SO',data=Bl,color='green')

# %%
sns.jointplot(x='W',y='SB',data=Bl,color='green')

# %%
sns.jointplot(x='W',y='RA',data=Bl,color='green')

# %%
sns.jointplot(x='W',y='ER',data=Bl,color='green')

# %%
sns.jointplot(x='W',y='ERA',data=Bl,color='green')

# %%
sns.jointplot(x='W',y='CG',data=Bl,color='green')

# %%
sns.jointplot(x='W',y='SHO',data=Bl,color='green')

# %%
sns.jointplot(x='W',y='SV',data=Bl,color='green')

# %%
sns.jointplot(x='W',y='E',data=Bl,color='green')

# %%
Bl['W'].plot.box()

# %%
Bl['R'].plot.box()

# %%
Bl['AB'].plot.box()

# %%
Bl['H'].plot.box()

# %%
Bl['2B'].plot.box()

# %%
Bl['3B'].plot.box()

# %%
Bl['HR'].plot.box()

# %%
Bl['BB'].plot.box()

# %%
Bl['SO'].plot.box()

# %%
Bl['SB'].plot.box()

# %%
Bl['RA'].plot.box()

# %%
Bl['ER'].plot.box()

# %%
Bl['ERA'].plot.box()

# %%
Bl['CG'].plot.box()

# %%
Bl['SHO'].plot.box()

# %%
Bl['SV'].plot.box()

# %%
Bl['E'].plot.box()

# %%
sns.heatmap(Bl.corr(),vmax = 1, vmin = 0,annot = True)
plt.show()

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(Bl))
z
# Out:
# array([[1.3654086 , 0.66538462, 0.84773126, 1.66368512, 1.42017307,
#         1.04119304, 0.7872986 , 1.53490242, 2.69762957, 0.91388329,
#         0.66623393, 0.50511008, 0.50695519, 0.5398062 , 0.81462859,
#         1.67160651, 0.46146963],
#        [0.1978383 , 0.17962404, 0.71109353, 0.97068076, 0.12740339,
#         1.23580856, 0.24396668, 0.5365919 , 0.15487844, 0.60182558,
#         0.16597077, 0.24892985, 0.25459752, 0.5398062 , 0.1728    ,
#         0.24987932, 0.60719689],
#        [0.00324325, 0.30766209, 1.1152333 , 0.15189137, 1.58879521,
#         0.22380785, 0.7233772 , 1.13914361, 0.89398189, 0.11144918,
#         0.68033909, 0.75162313, 0.64134684, 2.77264091, 0.32091429,
#         0.65485616, 1.11724227],
#        [0.48324437, 1.20480139, 0.24152162, 0.40108814, 0.82812203,
#         0.41842337, 0.8831807 , 1.16053598, 0.16860185, 0.69098493,
#         0.18007593, 0.10392217, 0.05301004, 1.3004422 , 0.56777144,
#         0.78410408, 0.48575751],
# ...

# %%
thershold=3
print(np.where(z>2))
# Out:
# (array([ 0,  2,  5,  5,  8, 11, 14, 15, 15, 15, 15, 16, 17, 17, 19, 22, 23,
#        23, 25, 27, 29, 29, 29], dtype=int64), array([ 8, 13,  1,  6, 15,  6, 16, 10, 11, 12, 15, 16,  8, 14,  9,  4,  1,
#         6, 14,  9, 10, 11, 12], dtype=int64))

# %%
Bl_new=Bl[(z<2).all(axis=1)]

# %%
Bl=Bl_new

# %%
Bl['E'].plot.box()

# %%
x=Bl.drop('W',axis=1)

# %%
y=Bl['W']

# %%
x.shape
# Out:
# (15, 16)

# %%
y.shape
# Out:
# (15,)

# %%
y=y.values.reshape(-1,1)

# %%
y.shape
# Out:
# (15, 1)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=14,random_state=42)

# %%
x_train.shape
# Out:
# (14, 16)

# %%
x_test.shape
# Out:
# (1, 16)

# %%
y_train.shape
# Out:
# (14, 1)

# %%
y_test.shape
# Out:
# (1, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
pred=lm.predict(x_test)

# %%
print(pred)
# Out:
# [[80.51559079]]

# %%
lm.coef_
# Out:
# array([[-0.03814832, -0.12975143,  0.09475844,  0.38641872,  0.09219675,
#          0.20738831, -0.0833511 , -0.02600032, -0.08657544,  0.00171758,
#         -0.09131307, -0.01296285,  1.41660249, -1.08626751,  0.73169782,
#          0.09723787]])

# %%
lm.intercept_
# Out:
# array([624.23125631])

# %%
lm.score(x_train,y_train)
# Out:
# 1.0

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
print('error')
print("mean absolute error:",mean_absolute_error(y_test,pred))
print("mean square error",mean_squared_error(y_test,pred))
print('rooot mean square error',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# error
# mean absolute error: 12.515590789160228
# mean square error 156.64001280171234
# rooot mean square error 12.515590789160228

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,pred))
# Out:
# nan

# %%
from sklearn.externals import joblib 
joblib.dump(lm,'baseball.pkl')
# Out:
# ['baseball.pkl']
